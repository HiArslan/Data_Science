# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tex=pd.read_csv("FAOSTAT_data.csv")
tex.head()
# Out:
#   Domain Code                        Domain  Area Code        Area  \
# 0         TCL  Crops and livestock products        100       India
# 1         TCL  Crops and livestock products        100       India
# 2         TCL  Crops and livestock products         16  Bangladesh
# 3         TCL  Crops and livestock products         16  Bangladesh
# 4         TCL  Crops and livestock products        165    Pakistan
#
#    Element Code          Element  Item Code            Item  Year Code  Year  \
# 0          5610  Import Quantity       1901  Textile Fibres       2000  2000
# 1          5910  Export Quantity       1901  Textile Fibres       2000  2000
# 2          5610  Import Quantity       1901  Textile Fibres       2000  2000
# 3          5910  Export Quantity       1901  Textile Fibres       2000  2000
# 4          5610  Import Quantity       1901  Textile Fibres       2000  2000
#
#      Unit   Value Flag                                   Flag Description
# ...

# %%
tex.shape
# Out:
# (126, 14)

# %%
tex.nunique()
# Out:
# Domain Code           1
# Domain                1
# Area Code             3
# Area                  3
# Element Code          2
# Element               2
# Item Code             1
# Item                  1
# Year Code            21
# Year                 21
# Unit                  1
# Value               126
# Flag                  1
# Flag Description      1
# dtype: int64

# %%
tex.isnull().sum()
# Out:
# Domain Code         0
# Domain              0
# Area Code           0
# Area                0
# Element Code        0
# Element             0
# Item Code           0
# Item                0
# Year Code           0
# Year                0
# Unit                0
# Value               0
# Flag                0
# Flag Description    0
# dtype: int64

# %%
tex.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag',
#        'Flag Description'],
#       dtype='object')

# %%
tex.dtypes
# Out:
# Domain Code         object
# Domain              object
# Area Code            int64
# Area                object
# Element Code         int64
# Element             object
# Item Code            int64
# Item                object
# Year Code            int64
# Year                 int64
# Unit                object
# Value                int64
# Flag                object
# Flag Description    object
# dtype: object

# %%
tex["Value"]=tex["Value"]*1000

# %%
x=tex["Year"]
y=tex["Value"]
y.head()
# Out:
# 0    347667000
# 1     57219000
# 2    188138000
# 3    335210000
# 4    148988000
# Name: Value, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.lineplot(
    data=tex,
    x="Year", y=tex["Value"], palette="dark",hue="Area",
    markers=True,ci=20,dashes=False
)
# sns.scatterplot(x="Year",y="Value",hue="Area",data=tex,palette="deep",style="dotted")
# sns.lineplot(x="Year",y="Value",hue="Area",data=tex,palette="dark")
# sns.lineplot(x="Year",y="Value",hue="Area",data=tex,palette="dark")
sns.set_theme(style="darkgrid")
plt.xlabel("Year",size=15,weight="bold")
plt.ylabel("Value(Kilo_Tonnes)",size=15,weight="bold")
plt.title("Export and import quantity of Textile Fibers",size=17,weight="bold")
plt.savefig("Textile Fibers.png",dpi=300)
plt.show()
