# %% [markdown]
# ## Flights dataset of seaborn line and bar plots practice

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set_theme(style="ticks",color_codes=True)
accident=sns.load_dataset("flights")
accident
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set_theme(style="ticks",color_codes=True)
flights=sns.load_dataset("flights")
plt.figure(figsize=(10,8))
sns.barplot(x="year" , y="passengers"  , data=flights , ci=None , saturation=1.5 )
plt.title("Bar Plot of seaborn_flights dataset")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# sns.set_theme(style="ticks",color_codes=True)
flights=sns.load_dataset("flights")
plt.figure(figsize=(12,8))
sns.lineplot(x="year" , y="passengers"  , data=flights )
plt.title("Line plot of seaborn_flights dataset")
plt.show()
